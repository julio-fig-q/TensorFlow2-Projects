# %% [markdown]
# # We are now going to evaluate the performance of our trained model and put it into action by getting its prediction in *unseen* data.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Building model 
model = Sequential([
    Dense(1, activation='sigmoid', input_shape=(12,)),
])

# Compiling model (getting it ready)
model.compile(
    optimizer='sgd', loss='binary_crossentropy',
    metrics=['accuracy'])

# Training the model
model.fit(X_train, y_train) # big training and labels arrays.

# To evaluate the model we simply test it:

model.evaluate(X_test, y_test) # data not used in training

# %% [markdown]
# This method called ``` model.evaluate ``` will iterate through the ```X_test, y_test ``` and return the loss and metric *in that test set*. So we do the following:

# %%
loss, accuracy = model.evaluate(X_test, y_test)

# %% [markdown]
# # To **use** the model to predict the outcomes of new data we do the following

# %%
# X_sample = (num_samples, 12)

pred = model.predict(X_sample)

# For exmaple (for binary):

# X_sample: (2, 12)
# pred: [[0.0723],
#        [0.8794]]

# For exmaple (for categorical):

# X_sample: (2, 12)
# pred: [[0.0723, 0.00123, 0.9823],
#        [0.8794, 0.03000, 0.1000]]
